# %% [markdown]
# # Run Experiments in Playground

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["LANGSMITH_API_KEY"] = ""

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a toy example dataset to run experiments over for a prompt

# %%
from langsmith import Client

example_inputs = [
("What color is the sky?", "The sky is blue"),
("What color is grass?", "Grass is green"),
("What color is dirt?", "Dirt is brown"),
]

client = Client()
dataset_name = "Sample Questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Sample questions about color",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['82d6f800-7d32-4a80-9eb8-4b6e37924136',
#   '4f4a05a9-ae4c-4eb7-aa0d-bb1c1d32a147',
#   'e8fcc9e5-6ebc-4e1f-96dd-34ab1ac655b1'],
#  'count': 3}

# %% [markdown]
# ### Below is the view in "Experiments" page in Playground, showing the reference outputs, the true outputs of the model and the tokens used for each prompt.

# %% [markdown]
# ![Screenshot 2025-10-10 161940.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **MY EXAMPLES**

# %%
example_inputs = [
("Who was known as the ""King of Pop""?", "Michael Jackson"),
("What is the most popular instrument in the world?", "Guitar is the most popular instrument"),
("Who was the most streamed Spotify artist in 2024?", "Taylor Swift"),
("Which is the most streamed song globally?", "Sabrina Carpenter - Espresso"),
("Which is the most famous instrument in India?", "Sitar is the most popular instrument in India"),
]

client = Client()
dataset_name = "Musical Questions"

dataset = client.create_dataset(
  dataset_name=dataset_name, description="Some questions about music and musical artists",
)

inputs = [{"question": input_prompt} for input_prompt, _ in example_inputs]
outputs = [{"output": output_answer} for _, output_answer in example_inputs]

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['044e9828-134c-49b2-9372-6a7ff960c47b',
#   '4cd76647-1438-40c1-9bb2-ecc142958544',
#   '894b36f6-6664-462c-9a7f-f0033d6124e6',
#   'b98fea23-5fb2-462c-8e7f-df15b57fd8bc',
#   '05c00254-4c3d-4f29-af8a-a9eb0aeff2f1'],
#  'count': 5}

# %% [markdown]
# ### **Output on the Playground:**

# %% [markdown]
# *System Prompt:*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Outputs of the model, latency and token details used for each prompt.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

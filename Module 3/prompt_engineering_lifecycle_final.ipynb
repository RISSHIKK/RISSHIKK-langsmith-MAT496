# %% [markdown]
# # Prompt Engineering Lifecycle

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["GROQ_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"

# %% [markdown]
# ### Log a trace

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.12/dist-packages (0.3.31)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.3.78)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.33)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (2.11.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.78->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 222, in iter_dependencies
#     req = Requirement(req_string.strip())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/requirements.py", line 36, in __init__
#     parsed = _parse_requirement(requirement_string)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 62, in parse_requirement
#     return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 80, in _parse_requirement
#     url, specifier, marker = _parse_requirement_details(tokenizer)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 124, in _parse_requirement_details
#     marker = _parse_requirement_marker(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 151, in _parse_requirement_marker
#     marker = _parse_marker(tokenizer)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 266, in _parse_marker
#     expression = [_parse_marker_atom(tokenizer)]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 288, in _parse_marker_atom
#     marker: MarkerAtom = _parse_marker(tokenizer)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 266, in _parse_marker
#     expression = [_parse_marker_atom(tokenizer)]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 291, in _parse_marker_atom
#     marker = _parse_marker_item(tokenizer)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 305, in _parse_marker_item
#     marker_var_right = _parse_marker_var(tokenizer)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 317, in _parse_marker_var
#     return process_python_str(tokenizer.read().text)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/packaging/_parser.py", line 332, in process_python_str
#     value = ast.literal_eval(python_str)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/ast.py", line 66, in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/ast.py", line 52, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.12/logging/__init__.py", line 1576, in critical
#     def critical(self, msg, *args, **kwargs):
#
# KeyboardInterrupt
# ^C

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-0.3.8-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain_groq) (0.3.78)
# Collecting groq<1,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.32.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (0.4.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain_groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (2.5.0)
# Downloading langchain_groq-0.3.8-py3-none-any.whl (16 kB)
# Downloading groq-0.32.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: groq, langchain_groq
# Successfully installed groq-0.32.0 langchain_groq-0.3.8

# %%
from app import langsmith_rag

question = "How do I set up tracing to LangSmith with @traceable?"
langsmith_rag(question)
# Out:
# /content/app.py:34: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embd = HuggingFaceEmbeddings(model_name=HF_EMBEDDING_MODEL_NAME) # Changed to HuggingFace Embeddings
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Fetching pages: 100%|##########| 197/197 [00:26<00:00,  7.39it/s]
# 'Set the environment variables\u202f`LANGSMITH_TRACING=true`\u202f(to enable tracing) and\u202f`LANGSMITH_API_KEY=<your‑key>`\u202f(and optionally\u202f`LANGSMITH_PROJECT=<project‑name>`). Then import the decorator and wrap any function you want to trace, e.g.:\n\n```python\nfrom langsmith import traceable\n\n@traceable\ndef my_func(...):\n    ...\n```\n\nWhen calling a sync function wrapped with\u202f@traceable, use\u202f`await my_func(...)`\u202fso the trace is recorded correctly.'

# %% [markdown]
# ### Below is the screenshot of the above prompt created vizualized in Playground

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a dataset to evaluate this particular step of our application

# %%
from langsmith import Client

example_dataset = [
    (
        "How do I set up tracing to LangSmith with @traceable?",
        """ 2. Log a trace​\nOnce you've set up your environment, you can call LangChain runnables as normal.\nLangSmith will infer the proper tracing config:\n\nHow to log and view traces to LangSmith | 🦜️🛠️ LangSmith\n\n2. Log a trace​\nOnce you've set up your environment, wrap or decorate the custom functions/SDKs you want to trace.\nLangSmith will then infer the proper tracing config:\n\nSkip to main contentGo to API DocsSearchRegionUSEUGo to AppQuick startObservabilityConceptual GuideHow-to GuidesTracingAnnotate code for tracingToggle tracing on and offUpload files with tracesLog traces to specific projectSet a sampling rate for tracesAdd metadata and tags to tracesImplement distributed tracingAccess the current run (span) within a traced functionLog multimodal tracesLog retriever tracesLog custom LLM tracesPrevent logging of sensitive data in tracesQuery tracesShare or unshare a trace publiclyCompare tracesTrace generator functionsTrace with LangChain (Python and JS/TS)Trace with LangGraph (Python and JS/TS)Trace with Instructor (Python only)Trace with the Vercel AI SDK (JS/TS only)Trace without setting environment variablesTrace using the LangSmith REST APICalculate token-based costs for tracesTroubleshoot trace nesting[Beta] Bulk Exporting Trace DataTrace JS functions in serverless environmentsMonitoring and automationsTutorialsAdd observability to your LLM applicationEvaluationPrompt EngineeringDeployment (LangGraph Cloud)AdministrationSelf-hostingReferenceObservabilityHow-to GuidesTracingAnnotate code for tracingOn this pageAnnotate code for tracing\nThere are several ways to log traces to LangSmith.\ntipIf you are using LangChain (either Python or JS/TS), you can skip this section and go directly to the LangChain-specific instructions.\nUse @traceable / traceable​\nLangSmith makes it easy to log traces with minimal changes to your existing code with the @traceable decorator in Python and traceable function in TypeScript.\nnoteThe LANGSMITH_TRACING environment variable must be set to 'true' in order for traces to be logged to LangSmith, even when using @traceable or traceable. This allows you to toggle tracing on and off without changing your code.Additionally, you will need to set the LANGSMITH_API_KEY environment variable to your API key (see Setup for more information).By default, the traces will be logged to a project named default.\nTo log traces to a different project, see this section. \n\n""",
        "To set up tracing to LangSmith using the `@traceable` decorator in Python, first ensure that you have the `LANGSMITH_TRACING` environment variable set to 'true' and the `LANGSMITH_API_KEY` set to your API key. Then, you can simply decorate your functions like this:\n\n```python\nfrom langsmith import traceable\n\n@traceable\ndef my_function():\n    # Your code here\n    pass\n```\n\nThis will log traces for `my_function` automatically once the necessary environment variables are configured."
    ),
    (
        "How can I use the tracing context manager?",
        """Use the trace context manager (Python only)​\nIn Python, you can use the trace context manager to log traces to LangSmith. This is useful in situations where:\n\nYou want to log traces for a specific block of code.\nYou want control over the inputs, outputs, and other attributes of the trace.\nIt is not feasible to use a decorator or wrapper.\nAny or all of the above.\n\nIn some environments, it is not possible to set environment variables. In these cases, you can set the tracing configuration programmatically.\nRecently changed behaviorDue to a number of asks for finer-grained control of tracing using the trace context manager,\nwe changed the behavior of with trace to honor the LANGSMITH_TRACING environment variable in version 0.1.95 of the Python SDK. You can find more details in the release notes.\nThe recommended way to disable/enable tracing without setting environment variables is to use the with tracing_context context manager, as shown in the example below.\nPythonTypeScriptThe recommended way to do this in Python is to use the tracing_context context manager. This works for both code annotated with traceable and code within the trace context manager.\n\nSkip to main contentGo to API DocsSearchRegionUSEUGo to AppQuick startObservabilityConceptual GuideHow-to GuidesTracingAnnotate code for tracingToggle tracing on and offUpload files with tracesLog traces to specific projectSet a sampling rate for tracesAdd metadata and tags to tracesImplement distributed tracingAccess the current run (span) within a traced functionLog multimodal tracesLog retriever tracesLog custom LLM tracesPrevent logging of sensitive data in tracesQuery tracesShare or unshare a trace publiclyCompare tracesTrace generator functionsTrace with LangChain (Python and JS/TS)Trace with LangGraph (Python and JS/TS)Trace with Instructor (Python only)Trace with the Vercel AI SDK (JS/TS only)Trace without setting environment variablesTrace using the LangSmith REST APICalculate token-based costs for tracesTroubleshoot trace nesting[Beta] Bulk Exporting Trace DataTrace JS functions in serverless environmentsMonitoring and automationsTutorialsAdd observability to your LLM applicationEvaluationPrompt EngineeringDeployment (LangGraph Cloud)AdministrationSelf-hostingReferenceObservabilityHow-to GuidesTracingTroubleshoot trace nestingOn this pageTroubleshoot trace nesting\nWhen tracing with the LangSmith SDK, LangGraph, and LangChain, tracing should automatically propagate the correct context so that code executed within a parent trace will be rendered in the expected location in the UI.\nIf you see a child run go to a separate trace (and appear on the top level), it may be caused by one of the following known \"edge cases\".\nPython​\nThe following outlines common causes for \"split\" traces when building with python.\nContext propagation using asyncio​\nWhen using async calls (especially with streaming) in Python versions < 3.11, you may encounter issues with trace nesting. This is because Python's asyncio only added full support for passing context in version 3.11.\nWhy​\nLangChain and LangSmith SDK use contextvars to propagate tracing information implicitly. In Python 3.11 and above, this works seamlessly. However, in earlier versions (3.8, 3.9, 3.10), asyncio tasks lack proper contextvar support, which can lead to disconnected traces.\nTo resolve​\n\nContext propagation using threading​\nIt's common to start tracing and want to apply some parallelism on child tasks all within a single trace. Python's stdlib ThreadPoolExecutor by default breaks tracing.\nWhy​\nPython's contextvars start empty within new threads. Here are two approaches to handle maintain trace contiguity:\nTo resolve​\n\n\nUsing LangSmith's ContextThreadPoolExecutor\nLangSmith provides a ContextThreadPoolExecutor that automatically handles context propagation:\nfrom langsmith.utils import ContextThreadPoolExecutorfrom langsmith import traceable@traceabledef outer_func():    with ContextThreadPoolExecutor() as executor:        inputs = [1, 2]        r = list(executor.map(inner_func, inputs))@traceabledef inner_func(x):    print(x)outer_func()\n\n\nManually providing the parent run tree\nAlternatively, you can manually pass the parent run tree to the inner function:\nfrom langsmith import traceable, get_current_run_treefrom concurrent.futures import ThreadPoolExecutor@traceabledef outer_func():    rt = get_current_run_tree()    with ThreadPoolExecutor() as executor:        r = list(            executor.map(                lambda x: inner_func(x, langsmith_extra={\"parent\": rt}), [1, 2]            )        )@traceabledef inner_func(x):    print(x)outer_func()\nIn this approach, we use get_current_run_tree() to obtain the current run tree and pass it to the inner function using the langsmith_extra parameter. \n\n """,
        "You can use the tracing context manager by wrapping the code you want to trace with the `with trace_context:` statement. Here's a simple example:\n\n```python\nfrom langsmith import trace_context\n\nwith trace_context:\n    # Your traceable code here\n    print(\"Tracing this block of code.\")\n``` \n\nThis will log traces to LangSmith for the specified code block."
    ),
    (
        "How can I use RunTree?",
        """PythonTypeScriptimport openaifrom langsmith.run_trees import RunTree# This can be a user input to your appquestion = \"Can you summarize this morning's meetings?\"# Create a top-level runpipeline = RunTree(  name=\"Chat Pipeline\",  run_type=\"chain\",  inputs={\"question\": question})# This can be retrieved in a retrieval stepcontext = \"During this morning's meeting, we solved all world conflict.\"messages = [  { \"role\": \"system\", \"content\": \"You are a helpful assistant. Please respond to the user's request only based on the given context.\" },  { \"role\": \"user\", \"content\": f\"Question: {question}\\nContext: {context}\"}]# Create a child runchild_llm_run = pipeline.create_child(  name=\"OpenAI Call\",  run_type=\"llm\",  inputs={\"messages\": messages},)# Generate a completionclient = openai.Client()chat_completion = client.chat.completions.create(  model=\"gpt-4o-mini\", messages=messages)# End the runs and log themchild_llm_run.end(outputs=chat_completion)child_llm_run.postRun()pipeline.end(outputs={\"answer\": chat_completion.choices[0].message.content})pipeline.postRun()import OpenAI from \"openai\";import { RunTree } from \"langsmith\";// This can be a user input to your appconst question = \"Can you summarize this morning's meetings?\";const pipeline = new RunTree({  name: \"Chat Pipeline\",  run_type: \"chain\",  inputs: { question }});await pipeline.postRun();// This can be retrieved in a retrieval stepconst context = \"During this morning's meeting, we solved all world conflict.\";const messages = [  { role: \"system\", content: \"You are a helpful assistant. Please respond to the user's request only based on the given context.\" },  { role: \"user\", content: `Question: ${question}Context: ${context}` }];// Create a child runconst childRun = await pipeline.createChild({  name: \"OpenAI Call\",\n\nPythonTypeScriptimport openaifrom langsmith.run_trees import RunTree# This can be a user input to your appquestion = \"Can you summarize this morning's meetings?\"# Create a top-level runpipeline = RunTree(  name=\"Chat Pipeline\",  run_type=\"chain\",  inputs={\"question\": question})await pipeline.postRun();# This can be retrieved in a retrieval stepcontext = \"During this morning's meeting, we solved all world conflict.\"messages = [  { \"role\": \"system\", \"content\": \"You are a helpful assistant. Please respond to the user's request only based on the given context.\" },  { \"role\": \"user\", \"content\": f\"Question: {question}\\nContext: {context}\"}]# Create a child runchild_llm_run = pipeline.create_child(  name=\"OpenAI Call\",  run_type=\"llm\",  inputs={\"messages\": messages},)# Generate a completionclient = openai.Client()chat_completion = client.chat.completions.create(  model=\"gpt-3.5-turbo\", messages=messages)# End the runs and log themchild_llm_run.end(outputs=chat_completion)child_llm_run.postRun()pipeline.end(outputs={\"answer\": chat_completion.choices[0].message.content})pipeline.postRun()import OpenAI from \"openai\";import { RunTree } from \"langsmith\";// This can be a user input to your appconst question = \"Can you summarize this morning's meetings?\";const pipeline = new RunTree({  name: \"Chat Pipeline\",  run_type: \"chain\",  inputs: { question }});// This can be retrieved in a retrieval stepconst context = \"During this morning's meeting, we solved all world conflict.\";const messages = [  { role: \"system\", content: \"You are a helpful assistant. Please respond to the user's request only based on the given context.\" },  { role: \"user\", content: `Question: ${question}Context: ${context}` }];// Create a child runconst childRun = await pipeline.createChild({  name: \"OpenAI\n\nAlternatively, you can convert LangChain's RunnableConfig to a equivalent RunTree object by using RunTree.fromRunnableConfig or pass the RunnableConfig as the first argument of traceable-wrapped function.\n\nRunTree({  run_type: \"llm\",  name: \"OpenAI Call RunTree\",  inputs: { messages },  tags: [\"my-tag\"],  extra: {metadata: {\"my-key\": \"my-value\"}}})await rt.postRun();const chatCompletion = await client.chat.completions.create({  model: \"gpt-3.5-turbo\",  messages: messages,});// End and submit the runawait rt.end(chatCompletion)await rt.patchRun()from langchain_openai import ChatOpenAIfrom langchain_core.prompts import ChatPromptTemplatefrom langchain_core.output_parsers import StrOutputParserprompt = ChatPromptTemplate.from_messages([(\"system\", \"You are a helpful AI.\"),(\"user\", \"{input}\")])chat_model = ChatOpenAI()output_parser = StrOutputParser()# Tags and metadata can be configured with RunnableConfigchain = (prompt | chat_model | output_parser).with_config({\"tags\": [\"top-level-tag\"], \"metadata\": {\"top-level-key\": \"top-level-value\"}})# Tags and metadata can also be passed at runtimechain.invoke({\"input\": \"What is the meaning of life?\"}, {\"tags\": [\"shared-tags\"], \"metadata\": {\"shared-key\": \"shared-value\"}})import { ChatOpenAI } from \"@langchain/openai\";import { ChatPromptTemplate } from \"@langchain/core/prompts\";import { StringOutputParser } from \"@langchain/core/output_parsers\";const prompt = ChatPromptTemplate.fromMessages([[\"system\", \"You are a helpful AI.\"],[\"user\", \"{input}\"]])const model = new ChatOpenAI({ modelName: \"gpt-3.5-turbo\" });const outputParser = new StringOutputParser();// Tags and metadata can be configured with RunnableConfigconst chain = (prompt.pipe(model).pipe(outputParser)).withConfig({\"tags\": [\"top-level-tag\"], \"metadata\": {\"top-level-key\": \"top-level-value\"}});// Tags and metadata can also be \n\n""",
        "You can use `RunTree` by creating a pipeline where you define its name, type, and inputs. For example:\n\n```python\nfrom langsmith.run_trees import RunTree\n\npipeline = RunTree(name=\"My Pipeline\", run_type=\"chain\", inputs={\"question\": \"Your question here\"})\n```\n\nYou can then create child runs and manage them accordingly within the pipeline."
    ),
]

client = Client()
dataset_name = "Technical Questions"

# Create dataset
dataset = client.create_dataset(
    dataset_name=dataset_name, description="Technical questions about LangSmith"
)

# Prepare inputs and outputs
inputs = [{"question": q, "context": c} for q, c, _ in example_dataset]
outputs = [{"output": o} for _, _, o in example_dataset]

# Create examples in the dataset
client.create_examples(
    inputs=inputs,
    outputs=outputs,
    dataset_id=dataset.id,
)
# Out:
# {'example_ids': ['8721ad46-959a-4136-b77b-e0e5d1a32d46',
#   '74f1cc3b-12b4-4bc9-a0b1-a788d8b9a388',
#   '7db14f45-2501-44f4-812d-61aa1d2470d0'],
#  'count': 3}

# %% [markdown]
# ### Output of the prompt based on the given dataset:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Update our Application to use Prompt Hub

# %% [markdown]
# We're going to pretty much define the same RAG application as before - with one crucial improvement.
#
# Instead of pulling our `RAG_PROMPT` from utils.py, we're going to connect to the Prompt Hub in LangSmith.
#
# Let's add the code snippet that will pull down our prompt that we just iterated on!

# %%
# Create a LANGSMITH_API_KEY in Settings > API Keys
from langsmith import Client
client = Client()
prompt = client.pull_prompt("rag_with_code", include_model=True)

# %%
import os
import tempfile
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders.sitemap import SitemapLoader
from langchain_community.vectorstores import SKLearnVectorStore
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langsmith import traceable
from langsmith.client import convert_prompt_to_openai_format
from typing import List
import nest_asyncio

HF_EMBEDDING_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
GROQ_MODEL_NAME = "openai/gpt-oss-120b"
MODEL_PROVIDER = "groq"
APP_VERSION = 1.0

groq_chat = ChatGroq(temperature=0, model_name=GROQ_MODEL_NAME)

def get_vector_db_retriever():
    persist_path = os.path.join(tempfile.gettempdir(), "union.parquet")
    embd = HuggingFaceEmbeddings(model_name=HF_EMBEDDING_MODEL_NAME)

    # If vector store exists, then load it
    if os.path.exists(persist_path):
        vectorstore = SKLearnVectorStore(
            embedding=embd,
            persist_path=persist_path,
            serializer="parquet"
        )
        return vectorstore.as_retriever(lambda_mult=0)

    # Otherwise, index LangSmith documents and create new vector store
    ls_docs_sitemap_loader = SitemapLoader(web_path="https://docs.smith.langchain.com/sitemap.xml", continue_on_failure=True)
    ls_docs = ls_docs_sitemap_loader.load()

    text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=500, chunk_overlap=0
    )
    doc_splits = text_splitter.split_documents(ls_docs)

    vectorstore = SKLearnVectorStore.from_documents(
        documents=doc_splits,
        embedding=embd,
        persist_path=persist_path,
        serializer="parquet"
    )
    vectorstore.persist()
    return vectorstore.as_retriever(lambda_mult=0)

nest_asyncio.apply()
retriever = get_vector_db_retriever()

"""
retrieve_documents
- Returns documents fetched from a vectorstore based on the user's question
"""
@traceable(run_type="chain")
def retrieve_documents(question: str):
    return retriever.invoke(question)

"""
generate_response
- Calls `call_groq` to generate a model response after formatting inputs
"""
@traceable(run_type="chain")
def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    # TODO: Let's use our prompt pulled from Prompt Hub instead of manually formatting here!

    messages = [prompt.invoke({"context":formatted_docs, "question": question})]
    # messages = convert_prompt_to_openai_format(formatted_prompt)["messages"] # Removed OpenAI format conversion
    return call_groq(messages)

"""
call_groq
- Returns the chat completion output from Groq
"""
@traceable(
    run_type="llm",
    metadata={
        "ls_provider": MODEL_PROVIDER,
        "ls_model_name": GROQ_MODEL_NAME
    }
)
def call_groq(messages: List[dict]) -> str:
    # Groq Chat takes a list of messages as input
    return groq_chat.invoke(messages)


"""
langsmith_rag
- Calls `retrieve_documents` to fetch documents
- Calls `generate_response` to generate a response based on the fetched documents
- Returns the model response
"""
@traceable(run_type="chain")
def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    # The response structure might be different for Groq,
    # you might need to adjust this line based on the actual response format
    return response.content

# %%
question = "How do I set up tracing to LangSmith with @traceable?"
langsmith_rag(question)
# Out:
# '### Minimal set‑up\n\nTo turn on LangSmith tracing for any function you decorate with `@traceable`, you only need **two** environment variables:\n\n| Variable | What it does | Typical value |\n|----------|--------------|---------------|\n| `LANGSMITH_TRACING` | Switches tracing on/off. If it’s set to a truthy value (`"true"`, `"1"`, `"yes"` …) the `@traceable` decorator will send data to LangSmith. | `"true"` (or `"1"`) |\n| `LANGSMITH_API_KEY` | Authenticates your client with the LangSmith service. You can find this key in the **Settings → API Keys** section of the LangSmith UI. | `"sk‑…"` (your secret key) |\n\nThat’s it—once those two are present, any `@traceable`‑decorated function will automatically log inputs, outputs, latency, and any custom metadata you add.\n\n---\n\n### Optional (but often useful) variables\n\n| Variable | What it does | Typical value |\n|----------|--------------|---------------|\n| `LANGSMITH_PROJECT` | Overrides the default project name (`"default"`). Useful if you want to group runs under a specific project without having to pass `project_name=` on every call. | `"my‑awesome‑project"` |\n| `LANGSMITH_ENDPOINT` | Points the SDK at a custom LangSmith server (e.g., a self‑hosted deployment or a staging environment). | `"https://api.langsmith.com"` (default) |\n| `LANGSMITH_DEBUG` | Enables verbose logging of the SDK’s internal HTTP requests – handy while you’re troubleshooting. | `"true"` |\n| `LANGSMITH_TIMEOUT` | Network timeout (seconds) for calls to the LangSmith API. | `"30"` |\n| `LANGSMITH_MAX_RETRIES` | Number of automatic retries on transient failures. | `"3"` |\n\n---\n\n### Quick example\n\n```python\nimport os\nfrom langsmith import traceable   # pip install "langsmith[openai]"\nfrom openai import OpenAI\n\n# ---- Set the required env vars (you can also export them in your shell) ----\nos.environ["LANGSMITH_TRACING"] = "true"\nos.environ["LANGSMITH_API_KEY"] = "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx"\n# (optional) os.environ["LANGSMITH_PROJECT"] = "my‑awesome‑project"\n\n# ---- Decorate any function you want to trace ----\n@traceable\ndef generate_answer(prompt: str) -> str:\n    client = OpenAI()\n    resp = client.completions.create(\n        model="gpt-4o-mini",\n        prompt=prompt,\n        max_tokens=256,\n    )\n    return resp.choices[0].message.content\n\n# ---- Use it as usual ----\nif __name__ == "__main__":\n    answer = generate_answer("What is LangSmith?")\n    print(answer)\n```\n\nWhen you run the script:\n\n1. The `@traceable` wrapper captures the function’s **input arguments**, **output**, **execution time**, and any **metadata** you add (e.g., `@traceable(metadata={"model": "gpt-4o-mini"})`).\n2. It sends that data to LangSmith under the project you specified (or the default one).\n3. You can then view the run in the LangSmith UI → **Runs** → **Projects**.\n\n---\n\n### How to verify it’s working\n\n1. **Check the console** – if `LANGSMITH_DEBUG` is set to `"true"` you’ll see logs like `POST https://api.langsmith.com/v1/runs …`.\n2. **Visit the LangSmith dashboard** – you should see a new run appear almost instantly after the function finishes.\n3. **Inspect the run details** – inputs, outputs, latency, and any custom metadata you added will be displayed.\n\n---\n\n### TL;DR\n\n```bash\nexport LANGSMITH_TRACING=true\nexport LANGSMITH_API_KEY=sk-<your‑key>\n# optional:\n# export LANGSMITH_PROJECT=my-awesome-project\n# export LANGSMITH_DEBUG=true\n```\n\nWith those variables set, any function wrapped in `@traceable` will automatically log to LangSmith. Happy tracing!'

# %% [markdown]
# # **MY EXAMPLES**

# %%
question1 = "What is LangSmith?"
response1 = langsmith_rag(question1)
print(f"Answer: {response1}\n")
# Out:
# Answer: Below is a **step‑by‑step guide** to get the `@traceable` decorator up and running in your own code.
# It covers everything from installing the SDK, configuring authentication, using the decorator with both synchronous and asynchronous functions, customizing the trace, and troubleshooting common pitfalls.
#
# ---
#
# ## 1️⃣ Install the LangSmith SDK
#
# ```bash
# # Core SDK (includes the decorator)
# pip install langsmith
# # If you also want the OpenAI client (used in many examples)
# pip install openai
# ```
#
# > **Tip:** If you’re using a virtual environment (highly recommended) make sure it’s activated before running the install command.
#
# ---
#
# ## 2️⃣ Set Up Authentication & Global Settings
#
# LangSmith needs two pieces of information:
#
# | Variable | What it does | Example |
# |----------|--------------|---------|
# | `LANGSMITH_API_KEY` | Your secret API key (found in the LangSmith UI → Settings → API Keys). | `sk-abc123…` |
# | `LANGSMITH_TRACING` | Turns tracing on/off globally. | `"true"` or `"false"` |
#
# You can provide them **once** at the start of your program, via environment variables, or a `.env` file.
#
# ### 2.1 Using environment variables (recommended)
#
# ```python
# import os
#
# os.environ["LANGSMITH_API_KEY"] = "sk-xxxxxxxxxxxxxxxxxxxx"
# os.environ["LANGSMITH_TRACING"] = "true"   # set to "false" to disable globally
# ```
#
# ### 2.2 Using a `.env` file (with python‑dotenv)
#
# ```bash
# # .env
# LANGSMITH_API_KEY=sk-xxxxxxxxxxxxxxxxxxxx
# LANGSMITH_TRACING=true
# ```
#
# ```python
# # main.py
# from dotenv import load_dotenv
# load_dotenv()   # reads .env into os.environ
# ```
#
# > **Note:** If you forget to set the key, the SDK will raise `LangSmithError: Missing LANGSMITH_API_KEY`.
#
# ---
#
# ## 3️⃣ Import the Decorator
#
# ```python
# from langsmith import traceable
# ```
#
# That’s it—no extra imports are required.
#
# ---
#
# ## 4️⃣ Wrap Your Functions
#
# ### 4️⃣1 Basic (synchronous) usage
#
# ```python
# from langsmith import traceable
# from openai import OpenAI
#
# client = OpenAI()   # reuse the client if you can – cheaper & faster
#
# @traceable
# def summarize(text: str) -> str:
#     """Summarize a piece of text using OpenAI."""
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": f"Summarize:\n\n{text}"}],
#     )
#     return response.choices[0].message.content
# ```
#
# Calling `summarize("Long article …")` will automatically:
#
# 1. Create a **Run** in LangSmith.
# 2. Log the **input** (`text`) and **output** (the summary).
# 3. Capture any **exceptions** that bubble up.
# 4. Attach default metadata (e.g., Python version, SDK version).
#
# ### 4️⃣2 Asynchronous usage
#
# ```python
# from langsmith import traceable
# from openai import AsyncOpenAI
#
# async_client = AsyncOpenAI()
#
# @traceable
# async def translate(prompt: str, target_lang: str = "Spanish") -> str:
#     resp = await async_client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": f"Translate to {target_lang}:\n\n{prompt}"}],
#     )
#     return resp.choices[0].message.content
# ```
#
# You can call it with `await translate("Hello world!")`.
#
# ### 4️⃣3 Adding a custom name, tags, and metadata
#
# Sometimes you want a more descriptive run name or extra context (e.g., a request ID).
#
# ```python
# @traceable(
#     name="weather_query",               # overrides the default function name
#     tags=["weather", "api-call"],       # free‑form tags for filtering in UI
#     metadata={"request_id": "abc-123"} # any JSON‑serializable dict
# )
# def get_weather(city: str) -> str:
#     # ... call some weather API ...
#     return f"The weather in {city} is sunny."
# ```
#
# All three arguments are **optional**; you can pass any combination you like.
#
# ---
#
# ## 5️⃣ How the Decorator Works Under the Hood
#
# | Step | What Happens |
# |------|--------------|
# | **Entry** | The decorator creates a `Run` object (`client.runs.create`) with the function name, arguments, and any supplied metadata. |
# | **Execution** | Your original function runs **inside a `try/except` block**. |
# | **Success** | On return, the decorator records the output (`run.outputs`) and marks the run as `COMPLETED`. |
# | **Error** | If an exception is raised, the decorator records the exception details (`run.error`) and marks the run as `FAILED`, then re‑raises the exception so your code behaves normally. |
# | **Exit** | The run is **flushed** to the LangSmith server (batched by default for efficiency). |
#
# Because the decorator is thin and non‑intrusive, you can safely add it to any function without changing its signature or return type.
#
# ---
#
# ## 6️⃣ Advanced Customisation
#
# ### 6.1 Controlling the **client** used for tracing
#
# By default the decorator uses the **global client** (`langsmith.Client()`) which reads configuration from the environment. If you need a custom endpoint (e.g., a self‑hosted LangSmith instance) you can pass a client instance:
#
# ```python
# from langsmith import Client, traceable
#
# custom_client = Client(
#     api_key=os.getenv("LANGSMITH_API_KEY"),
#     base_url="https://my‑self‑hosted‑langsmith.example.com",
# )
#
# @traceable(client=custom_client, name="my_custom_run")
# def foo(x: int) -> int:
#     return x * 2
# ```
#
# ### 6.2 Disabling tracing for a single call
#
# Sometimes you want to **temporarily turn off** tracing (e.g., for a cheap health‑check). Use the context manager:
#
# ```python
# from langsmith import disable_tracing
#
# with disable_tracing():
#     result = summarize("Short text")   # No run will be sent
# ```
#
# ### 6.3 Overriding the **project** per run
#
# If you have multiple LangSmith projects, you can target a specific one:
#
# ```python
# @traceable(project_name="my‑experimental‑project")
# def experimental_feature(x):
#     ...
# ```
#
# If you omit `project_name`, the SDK falls back to the **default project** set in your LangSmith UI.
#
# ---
#
# ## 7️⃣ Common Pitfalls & How to Fix Them
#
# | Symptom | Likely Cause | Fix |
# |---------|--------------|-----|
# | **No runs appear in the UI** | `LANGSMITH_TRACING` is `"false"` or missing. | Set `LANGSMITH_TRACING=true`. |
# | **Authentication error** | Wrong or missing `LANGSMITH_API_KEY`. | Verify the key in LangSmith → Settings → API Keys. |
# | **Runs are missing arguments** | Function arguments are not JSON‑serializable (e.g., a file handle). | Convert to a serializable form before returning or pass `metadata` manually. |
# | **Runs are duplicated** | You wrapped a function **twice** (e.g., once manually and once via a higher‑level library). | Ensure only one `@traceable` is applied. |
# | **Slow performance** | Network latency on every call. | Use the default **batching** (the SDK buffers runs and sends them in bulk). You can also increase `batch_size` via `Client(..., batch_size=50)`. |
# | **Exception not re‑raised** | You swallowed the exception inside the function. | The decorator only re‑raises what bubbles out; handle errors inside the function if you need custom behaviour. |
#
# ---
#
# ## 8️⃣ Full End‑to‑End Example (Sync + Async + Customisation)
#
# ```python
# # -------------------------------------------------
# # file: app.py
# # -------------------------------------------------
# import os
# from dotenv import load_dotenv
# from langsmith import Client, traceable, disable_tracing
# from openai import OpenAI, AsyncOpenAI
#
# # 1️⃣ Load env vars (or set them manually)
# load_dotenv()                     # reads .env
# os.environ["LANGSMITH_TRACING"] = "true"
#
# # 2️⃣ Optional: create a custom client (e.g., custom endpoint)
# client = Client(
#     api_key=os.getenv("LANGSMITH_API_KEY"),
#     # base_url="https://my‑self‑hosted‑langsmith.example.com",  # if needed
# )
#
# # 3️⃣ Re‑use OpenAI clients (cheaper than re‑creating each call)
# sync_llm = OpenAI()
# async_llm = AsyncOpenAI()
#
# # -------------------------------------------------
# # Synchronous function
# # -------------------------------------------------
# @traceable(
#     client=client,
#     name="summarize_article",
#     tags=["nlp", "summarization"],
#     metadata={"model": "gpt-4o-mini"},
# )
# def summarize_article(text: str) -> str:
#     """Summarize a long article."""
#     resp = sync_llm.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": f"Summarize:\n\n{text}"}],
#     )
#     return resp.choices[0].message.content
#
# # -------------------------------------------------
# # Asynchronous function
# # -------------------------------------------------
# @traceable(
#     client=client,
#     name="translate_async",
#     tags=["translation"],
#     metadata={"target_lang": "German"},
# )
# async def translate_async(text: str, target_lang: str = "German") -> str:
#     resp = await async_llm.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": f"Translate to {target_lang}:\n\n{text}"}],
#     )
#     return resp.choices[0].message.content
#
# # -------------------------------------------------
# # Example usage
# # -------------------------------------------------
# if __name__ == "__main__":
#     # Normal run – will be traced
#     summary = summarize_article("Artificial intelligence ...")
#     print("Summary:", summary)
#
#     # Temporarily disable tracing for a cheap health‑check
#     with disable_tracing():
#         print("Health check:", summarize_article("Hello"))   # No run logged
#
#     # Async example (run with `python -m asyncio app.py` or any async runner)
#     import asyncio
#
#     async def main():
#         translation = await translate_async(
#             "The quick brown fox jumps over the lazy dog."
#         )
#         print("Translation:", translation)
#
#     asyncio.run(main())
# ```
#
# Running the script will create **two runs** in your default LangSmith project:
#
# | Run name            | Tags                | Status |
# |---------------------|---------------------|--------|
# | `summarize_article` | `nlp`, `summarization` | `COMPLETED` |
# | `translate_async`   | `translation`       | `COMPLETED` |
#
# You can view them in the LangSmith UI → **Runs**, filter by tags, and drill into the inputs/outputs.
#
# ---
#
# ## 9️⃣ Quick Reference Cheat‑Sheet
#
# | Decorator signature | Description |
# |---------------------|-------------|
# | `@traceable` | Use defaults (function name, no tags, global client). |
# | `@traceable(name="my_name")` | Override the run name. |
# | `@traceable(tags=["tag1","tag2"])` | Add searchable tags. |
# | `@traceable(metadata={"key":"value"})` | Attach arbitrary JSON‑serializable data. |
# | `@traceable(project_name="my‑project")` | Send the run to a specific LangSmith project. |
# | `@traceable(client=my_client)` | Use a custom `Client` (different endpoint, batch size, etc.). |
# | `@traceable(..., async_=True)` | **Not needed** – the decorator auto‑detects `async def`. |
#
# ---
#
# ## 10️⃣ Where to Go Next
#
# | Goal | Resource |
# |------|----------|
# | **Deep dive into LangSmith UI** | <https://docs.smith.langchain.com/ui> |
# | **Batching & performance tuning** | `Client(..., batch_size=100, flush_interval_seconds=5)` |
# | **Integrations with LangChain, LlamaIndex, etc.** | `pip install langchain[all]` then use `langchain.tracing.langsmith_tracer` |
# | **Custom callbacks / manual run handling** | `from langsmith import Run, Client` – see the SDK docs for `client.runs.*` methods. |
# | **Self‑hosted LangSmith** | Follow the “Deploy LangSmith on Kubernetes” guide in the docs. |
#
# ---
#
# ### TL;DR
#
# 1. **Install** `langsmith`.
# 2. **Set** `LANGSMITH_API_KEY` and `LANGSMITH_TRACING=true`.
# 3. **Import** `traceable` and **decorate** any function.
# 4. (Optional) Provide `name`, `tags`, `metadata`, `project_name`, or a custom `client`.
# 5. **Run** your code – the SDK automatically logs inputs, outputs, errors, and timing to LangSmith.
#
# That’s all you need to start visualising, debugging, and analysing your LLM‑powered pipelines! 🚀

# %%
question2 = "How can I compare traces in LangSmith?"
response2 = langsmith_rag(question2)
print(f"Answer: {response2}\n")
# Out:
# Answer: Here’s a quick, self‑contained example that shows exactly how to turn on LangSmith tracing with environment variables and then use the `@traceable` decorator to automatically log a call to the OpenAI API.
#
# ```python
# # -------------------------------------------------
# # 1️⃣  Set the required environment variables
# # -------------------------------------------------
# import os
#
# # Enable LangSmith tracing for the current process
# os.environ["LANGSMITH_TRACING"] = "true"
#
# # Insert your LangSmith API key (replace the placeholder)
# os.environ["LANGSMITH_API_KEY"] = "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx"
#
# # (Optional) Choose a project name – otherwise “default” is used
# # os.environ["LANGSMITH_PROJECT"] = "my‑awesome‑project"
# # -------------------------------------------------
#
#
# # -------------------------------------------------
# # 2️⃣  Install the needed packages (run once)
# # -------------------------------------------------
# # pip install openai langsmith
# # -------------------------------------------------
#
#
# # -------------------------------------------------
# # 3️⃣  Import the decorator and wrap your function
# # -------------------------------------------------
# from langsmith import traceable          # <-- the decorator
# from openai import OpenAI                # <-- OpenAI client (sync or async)
#
# # -----------------------------------------------------------------
# # Example 1: Synchronous version
# # -----------------------------------------------------------------
# @traceable
# def generate_answer_sync(prompt: str) -> str:
#     """Calls the OpenAI chat completion endpoint synchronously."""
#     client = OpenAI()
#     resp = client.chat.completions.create(
#         model="gpt-4o-mini",                     # pick any model you have access to
#         messages=[{"role": "user", "content": prompt}],
#     )
#     return resp.choices[0].message.content
#
#
# # -----------------------------------------------------------------
# # Example 2: Asynchronous version (recommended for FastAPI, etc.)
# # -----------------------------------------------------------------
# @traceable
# async def generate_answer_async(prompt: str) -> str:
#     """Calls the OpenAI chat completion endpoint asynchronously."""
#     client = OpenAI()
#     resp = await client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}],
#     )
#     return resp.choices[0].message.content
#
#
# # -----------------------------------------------------------------
# # 4️⃣  Use the function – the call will be automatically logged
# # -----------------------------------------------------------------
# if __name__ == "__main__":
#     # Synchronous call
#     answer_sync = generate_answer_sync("What is the capital of France?")
#     print("Sync answer:", answer_sync)
#
#     # Asynchronous call – run inside an event loop
#     import asyncio
#
#     async def run_async():
#         answer_async = await generate_answer_async(
#             "Explain the difference between supervised and unsupervised learning."
#         )
#         print("Async answer:", answer_async)
#
#     asyncio.run(run_async())
# ```
#
# ### What’s happening under the hood?
#
# | Step | What the code does | LangSmith effect |
# |------|-------------------|------------------|
# | **1️⃣ Set env vars** | `LANGSMITH_TRACING=true` tells the SDK to emit traces. `LANGSMITH_API_KEY` authenticates you. | All subsequent `@traceable` calls are sent to your LangSmith workspace. |
# | **2️⃣ Install packages** | `openai` provides the client; `langsmith` supplies the decorator and telemetry. | No tracing yet – just making the libraries available. |
# | **3️⃣ Decorate** | `@traceable` wraps the function. It captures inputs, outputs, execution time, any exceptions, and the underlying OpenAI request/response payloads (unless you mask them). | A **Run** object is created in LangSmith, linked to a **Project** (default = “default”). |
# | **4️⃣ Call** | When you invoke the function, the decorator starts a trace, runs the body, then finalizes the trace. | You’ll see the run appear in the LangSmith UI almost instantly, with a clickable view of the request/response, latency, token usage, etc. |
#
# ### Customising the trace (optional)
#
# If you want to add extra metadata (e.g., a user ID, experiment name, or version tag), you can pass arguments to the decorator:
#
# ```python
# @traceable(
#     name="generate_answer",
#     tags=["experiment-42", "v1.2"],
#     metadata={"user_id": "abc123", "source": "webapp"},
# )
# def generate_answer_sync(prompt: str) -> str:
#     ...
# ```
#
# These fields show up in the LangSmith UI and are searchable via the API.
#
# ### Quick sanity‑check
#
# After you run the script, head over to **https://smith.langchain.com/**, log in, and select the **default** project (or the project you set via `LANGSMITH_PROJECT`). You should see two runs:
#
# 1. `generate_answer_sync`
# 2. `generate_answer_async`
#
# Click on either run to explore:
#
# - **Inputs** – the prompt you sent.
# - **Outputs** – the model’s response.
# - **Metrics** – latency, token usage, cost (if you have cost tracking enabled).
# - **Trace view** – a visual DAG showing the OpenAI request as a child node of the Python function call.
#
# That’s it! With just a couple of environment variables and the `@traceable` decorator, you get full observability of your LLM calls in LangSmith. 🚀

# %%
question3 = "What is the purpose of the `traceable` decorator?"
response3 = langsmith_rag(question3)
print(f"Answer: {response3}\n")
# Out:
# Answer: Sure! Below is a quick, step‑by‑step guide to enable LangSmith tracing in your Python code, set the required environment variables, and wrap any function you want to monitor with the `@traceable` decorator.
#
# ---
#
# ## 1️⃣ Install the LangSmith SDK (if you haven’t already)
#
# ```bash
# pip install langsmith
# # If you also need the OpenAI client:
# pip install openai
# ```
#
# ---
#
# ## 2️⃣ Set the required environment variables
#
# You need two variables:
#
# | Variable | Value | Why it’s needed |
# |----------|-------|-----------------|
# | `LANGSMITH_TRACING` | `"true"` (or `"1"`/`"yes"` – any truthy string) | Turns tracing on for the SDK. |
# | `LANGSMITH_API_KEY` | Your LangSmith API key (e.g., `sk-…`) | Authenticates your runs with the LangSmith service. |
#
# ### a. **Temporarily (for the current session)**
#
# ```bash
# export LANGSMITH_TRACING=true
# export LANGSMITH_API_KEY=sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ```
#
# *On Windows PowerShell:*
#
# ```powershell
# $env:LANGSMITH_TRACING = "true"
# $env:LANGSMITH_API_KEY = "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx"
# ```
#
# ### b. **Permanently (e.g., in a `.env` file)**
#
# Create a file named `.env` in your project root:
#
# ```
# LANGSMITH_TRACING=true
# LANGSMITH_API_KEY=sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ```
#
# Then load it at runtime (e.g., with `python-dotenv`):
#
# ```bash
# pip install python-dotenv
# ```
#
# ```python
# from dotenv import load_dotenv
# load_dotenv()  # reads .env and populates os.environ
# ```
#
# ---
#
# ## 3️⃣ Import and use the `@traceable` decorator
#
# ```python
# import os
# from langsmith import traceable   # <-- the decorator
# from openai import OpenAI          # example client; replace with yours
#
# # Optional: make sure the env vars are set (useful when running from a script)
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxx"
# ```
#
# ### Example: Tracing a simple OpenAI call
#
# ```python
# @traceable
# def generate_answer(prompt: str) -> str:
#     """
#     Sends a prompt to OpenAI and returns the model's response.
#     The entire execution (inputs, outputs, latency, etc.) will be logged
#     to LangSmith because of the @traceable decorator.
#     """
#     client = OpenAI()
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     # Grab the assistant's reply
#     return response.choices[0].message.content
#
#
# # ---- Use the function as you normally would ----
# if __name__ == "__main__":
#     user_prompt = "What is LangSmith and why should I use it?"
#     answer = generate_answer(user_prompt)
#     print("Model answer:", answer)
# ```
#
# **What happens under the hood?**
#
# - When `generate_answer` is called, the decorator creates a **LangSmith Run**.
# - It records:
#   - Input arguments (`prompt`)
#   - Output (`answer`)
#   - Execution metadata (duration, timestamps, any exceptions)
#   - Any nested calls you also decorate with `@traceable`
# - All of this data appears in your LangSmith dashboard, where you can filter, compare, and visualize runs.
#
# ---
#
# ## 4️⃣ Async functions (if you’re using `async`/`await`)
#
# The decorator works with async functions as well:
#
# ```python
# @traceable
# async def async_generate_answer(prompt: str) -> str:
#     client = OpenAI()
#     response = await client.chat.completions.acreate(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response.choices[0].message.content
#
# # Calling it:
# import asyncio
#
# async def main():
#     answer = await async_generate_answer("Explain async tracing.")
#     print(answer)
#
# asyncio.run(main())
# ```
#
# ---
#
# ## 5️⃣ Verifying that tracing is active
#
# After you run a traced function, head over to the **LangSmith UI** (usually at `https://smith.langchain.com/`). You should see a new run appear in the **Runs** table with:
#
# - The function name (`generate_answer` or `async_generate_answer`)
# - Input payload (`prompt`)
# - Output payload (the model’s response)
# - Timing and any logged metadata
#
# If you don’t see anything:
#
# 1. Double‑check that `LANGSMITH_TRACING` is set to a truthy value.
# 2. Verify that `LANGSMITH_API_KEY` is correct and has the right permissions.
# 3. Look at the console output; the SDK prints a short warning if tracing is disabled.
#
# ---
#
# ## 6️⃣ Optional: Adding custom metadata or tags
#
# You can enrich a run with extra context:
#
# ```python
# @traceable
# def generate_answer(prompt: str, *, user_id: str) -> str:
#     # Attach custom metadata
#     from langsmith import get_current_run
#     run = get_current_run()
#     if run:
#         run.update(
#             tags=["user-interaction"],
#             metadata={"user_id": user_id, "source": "webapp"},
#         )
#     # Normal logic follows...
#     client = OpenAI()
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response.choices[0].message.content
# ```
#
# Now each run will carry the `user_id` and any tags you set, making it easier to filter later.
#
# ---
#
# ## 🎉 Quick Recap
#
# 1. **Set env vars** (`LANGSMITH_TRACING=true`, `LANGSMITH_API_KEY=sk-…`).
# 2. **Import** `traceable` from `langsmith`.
# 3. **Decorate** any function you want to monitor with `@traceable`.
# 4. **Call** the function as usual (or `await` if async).
# 5. **Check** the LangSmith dashboard for the recorded runs.
#
# That’s it! You now have end‑to‑end tracing for your LLM‑powered code. Happy debugging and observability! 🚀
